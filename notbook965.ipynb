# %%
#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time

nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\TECNICO DE ENFERMAGEM.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

for linha in range(4, 7+1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)

    #clica em adcionar novo usuario
    pagi.moveTo(806, 561)
    pagi.click()
    time.sleep(1)

    #encontra campo nome
    pagi.moveTo(940, 305)
    pagi.click()
    pagi.write(nome)
    time.sleep(1)

    #rola scroll ate função para evolução/prescição
    pagi.moveTo(1558, 339)
    pagi.mouseDown(x=1558, y=480)
    pagi.mouseUp()
    time.sleep(1)

    #seleciona a função para evolução/prescição
    pagi.moveTo(1092, 586)
    pagi.click()
    pagi.write('tec')
    time.sleep(1)
    pagi.press('down')
    pagi.press('enter')
    time.sleep(1)

    #encontra botão salvar
    pagi.moveTo(1519, 775)
    pagi.click() #clicar no botão salvar

    #encontra botão de seleção
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    pagi.moveTo(118, 240) #encontra o botão perfis
    time.sleep(1)
    pagi.click() #clica no botão perfis
    time.sleep(1)

    #encontra botão copia de perfil
    pagi.moveTo(192, 199)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario
    pagi.moveTo(56, 289)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario ref
    pagi.moveTo(419, 302)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #escreve a matricula do usuario referencia tecnico enfermagem
    pagi.write('6323172')
    time.sleep(1)

    #marca perfil e setor
    pagi.moveTo(350, 396) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    pagi.moveTo(505, 399) #perfil
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(nome)
    time.sleep(1)
    
    #clicar em filtrar
    pagi.moveTo(1513, 344)
    pagi.click()
    time.sleep(1.5)
    

    #encontra o botão copiar
    pagi.moveTo(713, 357)
    pagi.mouseDown(button='left', x=713, y=745)
    pagi.mouseUp()
    time.sleep(1)
    pagi.moveTo(386, 758)
    time.sleep(1)
    pagi.click()

    #clicar em ok no final (pop-up)
    pagi.moveTo(x=938, y=552)
    time.sleep(2)
    pagi.click()
    time.sleep(2)
    
    #encontra botão de seleção / voltar para aba Usuario
    time.sleep(1)
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    pagi.moveTo(x=101, y=375)
    pagi.click() 
    
#--------------------------------------------------------|=Indo para aba Usúario=|-------------------------------------
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write('963258')
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)
    
#--------------------------------------------------------|=Gera senha=|-------------------------------------
    #gera senha
    #encontrar o botão gerar senha
    pagi.moveTo(x=1525, y=224) #encontra botão gerar senha
    pagi.click() #clica botão gerar senha
    time.sleep(1)
    pagi.moveTo(x=790, y=462)#encontra campo para digitar senha
    time.sleep(1)
    pagi.write('123tasy') #escreve a senha '123tasy'
    time.sleep(1)
    pagi.moveTo(x=940, y=597) # encontra botão OK
    #pagi.click() #clica botão OK
    
#--------------------------------------------------------|=Indo para aba Usúario=|-------------------------------------
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write('963258')
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)
    
#--------------------------------------------------------|=Printar o nome/matricula do usuario criado=|------------------
    print(matricula)
    print(nome)

# %%
#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time

nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\TECNICO DE ENFERMAGEM.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

for linha in range(4, 7+1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    
    print(matricula)
    print(nome)
# Out:
# 6322552
# ADRIANA SOARES GOMES
# 6320596
# ADRIANA VAZ SOARES
# 6320417
# ADRIANE PONCIANO VIEIRA DA SILVA
# 6320963
# ADRIANO BATISTA DA SILVA

# %%
    from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time
    
    #encontra o botão copiar
    pagi.moveTo(713, 357)
    pagi.mouseDown(button='left', x=713, y=745)
    pagi.mouseUp()
    time.sleep(1)
    pagi.moveTo(386, 758)
    time.sleep(1)
    #pagi.click()

# %%
 pagi.moveTo(386, 758)

# %%
    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(nome)
    time.sleep(1)
    
    #clicar em filtrar
    pagi.moveTo(1513, 344)
    pagi.click()

# %%
pagi.position()
# Out:
# Point(x=940, y=597)

# %%
# test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time

nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\TECNICO DE ENFERMAGEM.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('vou começar')

for linha in range(8, len(sheet_selecionada['A']) +1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)

    #clica em adcionar novo usuario
    pagi.moveTo(806, 561)
    pagi.click()
    time.sleep(1)

    #encontra campo nome
    pagi.moveTo(940, 305)
    pagi.click()
    pagi.write(nome)
    time.sleep(1)
    
    #colocar senha para resetar em 180 dias
    pagi.moveTo(x=280, y=386) # encontrar campo para digatar a quantidade de dias
    time.sleep(0.5)
    pagi.click() #clica no campo
    pagi.write('180') #escreve a quantidade de dias
    time.sleep(0.5) 

    #rola scroll ate função para evolução/prescição
    pagi.moveTo(1558, 339)
    pagi.mouseDown(x=1558, y=480)
    pagi.mouseUp()
    time.sleep(1)

    #seleciona a função para evolução/prescição
    pagi.moveTo(1092, 586)
    pagi.click()
    pagi.write('tec')
    time.sleep(1)
    pagi.press('down')
    pagi.press('enter')
    time.sleep(1)

    #encontra botão salvar
    pagi.moveTo(1519, 775)
    pagi.click() #clicar no botão salvar

    #encontra botão de seleção
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    pagi.moveTo(118, 240) #encontra o botão perfis
    time.sleep(1)
    pagi.click() #clica no botão perfis
    time.sleep(1)

    #encontra botão copia de perfil
    pagi.moveTo(192, 199)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario
    pagi.moveTo(56, 289)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario ref
    pagi.moveTo(419, 302)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #escreve a matricula do usuario referencia tecnico enfermagem
    pagi.write('6323172')
    time.sleep(1)

    #marca perfil e setor
    pagi.moveTo(350, 396) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    pagi.moveTo(505, 399) #perfil
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(nome)
    time.sleep(1)
    
    #clicar em filtrar
    pagi.moveTo(1513, 344)
    pagi.click()
    time.sleep(1.5)
    

    #encontra o botão copiar
    pagi.moveTo(713, 357)
    pagi.mouseDown(button='left', x=713, y=745)
    pagi.mouseUp()
    time.sleep(1)
    pagi.moveTo(386, 758)
    time.sleep(1)
    pagi.click()

    #clicar em ok no final (pop-up)
    pagi.moveTo(x=938, y=552)
    time.sleep(2)
    pagi.click()
    time.sleep(2)
    
    #encontra botão de seleção / voltar para aba Usuario
    time.sleep(1)
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    pagi.moveTo(x=101, y=375)
    time.sleep(1)
    pagi.click() 
    
#--------------------------------------------------------|=Indo para Usúario filtrado=|-------------------------------------
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)
    
#--------------------------------------------------------|=Gera senha=|-------------------------------------
    #gera senha
    #encontrar o botão gerar senha
    pagi.moveTo(x=1525, y=224) #encontra botão gerar senha
    pagi.click() #clica botão gerar senha
    time.sleep(1)
    pagi.moveTo(x=790, y=462)#encontra campo para digitar senha
    time.sleep(1)
    pagi.write('123tasy') #escreve a senha '123tasy'
    time.sleep(1)
    pagi.moveTo(x=940, y=597) # encontra botão OK
    time.sleep(1)
    pagi.click() #clica botão OK (confirmar criação de senha)
    time.sleep(1.5)
    pagi.moveTo(x=948, y=544) #encontrar botão ok senha gerada com sucesso
    time.sleep(1.5)
    pagi.click() #clica botão ok senha gerada com sucesso
    
#--------------------------------------------------------|=Indo para filtro icone na tela=|-------------------------------------
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(x=50, y=278) #move mouse no filtro "icone na tala"
    time.sleep(1)
    pagi.click() #clica no filtro "icone na tala"

#--------------------------------------------------------|=Printar o nome/matricula do usuario criado=|------------------
    print(matricula)
    print(nome)
# Out:
# 1234567906
# teste106
# 1234567907
# teste107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15620/3458565318.py in <module>
#      28     nome = unidecode(str(nome2))
#      29
# ---> 30     pagi.alert('vou começar')
#      31     time.sleep(2)
#      32     #encontra campo usuario
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymsgbox\_native_win.py in alert(text, title, button, root, timeout, icon, _tkinter)
#      67         return pymsgbox._alertTkinter(text, title, button, root, timeout)
#      68
# ---> 69     messageBoxFunc(0, text, title, MB_OK | MB_SETFOREGROUND | MB_TOPMOST | icon)
#      70     return button
#      71
#
# KeyboardInterrupt:

# %%
    #encontra campo nome
    pagi.moveTo(940, 305)
    pagi.click()
    pagi.write(nome)
    time.sleep(1)
    
    #colocar senha para resetar em 180 dias
    pagi.moveTo(x=280, y=386) # encontrar campo para digatar a quantidade de dias
    time.sleep(0.5)
    pagi.click() #clica no campo
    pagi.write('180') #escreve a quantidade de dias
    time.sleep(0.5)

# %%
pagi.position()
# Out:
# Point(x=280, y=386)

# %%
#test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time

nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\teste123.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15620/1377579678.py in <module>
#      10
#      11 nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\teste123.xlsx"
# ---> 12 planilha_aberta = load_workbook(filename = nome_caminho_arquivo)
#
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     313
#     314     """
# --> 315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
#     317     reader.read()
#
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# --> 124         self.archive = _validate_archive(fn)
#     125         self.valid_files = self.archive.namelist()
#     126         self.read_only = read_only
#
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in _validate_archive(filename)
#      94             raise InvalidFileException(msg)
#      95
# ---> 96     archive = ZipFile(filename, 'r')
#      97     return archive
#      98
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1237             while True:
#    1238                 try:
# -> 1239                     self.fp = io.open(file, filemode)
#    1240                 except OSError:
#    1241                     if filemode in modeDict:
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\6324102\\Documents\\Alexandre\\PYTHON AUTOMATIZAÇÃO\\Jupyter\\lista_usuarios_tasy\teste123.xlsx'

# %%
pagi.position()
# Out:
# Point(x=50, y=278)

# %%
# test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time

nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\teste123.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

for linha in range(11, 16+1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    
    print(matricula)
    print(nome)
# Out:
# 1234567900
# teste100
# 1234567901
# teste101
# 1234567902
# teste102
# 1234567903
# teste103
# 1234567904
# teste104
# 1234567905
# teste105

# %%
x = 'print linha 1'

print('teste', x)
print('\n')
print(x)
# Out:
# teste print linha 1
#
#
# print linha 1
