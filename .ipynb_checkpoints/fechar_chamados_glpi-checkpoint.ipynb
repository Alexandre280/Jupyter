# %% [markdown]
# # ABRE NAVEGADOR E NO TASY

# %%
from selenium import webdriver as opções_selenium_aula
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as pagi
from openpyxl import load_workbook
import os
from unidecode import unidecode
import time
from datetime import datetime

meuNavegador = opções_selenium_aula.Chrome()
#meuNavegador.get("www.tasyweb.spdmafiliadas.org.br")

# %% [markdown]
# # EXECUTA PROCEDIMENTO NO TASY

# %%
nome_caminho_arquivo = "C:\\Users\\6324102\DocumentsPython Scripts\Jupyter\lista_usuarios_tasy\\medicos-sem-cns-02-07-2022.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Preenchendo cns função medico')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Preenchendo cns medico\n\nInicio', 'Data: ', data, '- Hora: ', hora)

#+++++====================++++==============CAMPOS TASY

campo_codigo = '//*[@id="detail_4_container"]/div[3]/div[2]/tasy-wtextboxlocator/div/div/div[1]/tasy-wtextbox/div/div/input'
botao_filtrar = '//*[@id="app-view"]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corpesf7/div/div[4]/div[2]/tasy-wfilter/div/div[2]/div/button'
botao_ver = '//*[@id="layout"]/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[2]/tasy-handlebar-new/div/div[1]/div/button[9]/span'
botao_ver_D = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corpesf7/div/div[2]/div[2]/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[2]/tasy-handlebar-new/div/div[1]/div/button[9]/span'
campo_cns = '//*[@id="detail_3_container"]/div[3]/div[8]/div[2]/tasy-wtextbox/div/div/input'
botao_salvar = '//*[@id="layout"]/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/div[2]/tasy-wmdetail/div[2]/div[3]/form/w-persistence-action-bar/w-persistence-action-bar-button[1]/tasy-wbutton/div'
botao_salvar_D = '//*[@id="layout"]/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/div[2]/tasy-wmdetail/div[2]/div[3]/form/w-persistence-action-bar/w-persistence-action-bar-button[1]/tasy-wbutton'
botao_funil_filtro = '//*[@id="layout"]/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/tasy-wlabel'
botao_fechar = '//*[@id="layout"]/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[2]/tasy-handlebar-new/div/div[1]/div/button[10]'
botao_fechar_D = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corpesf7/div/div[2]/div[2]/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[2]/tasy-handlebar-new/div/div[1]/div/button[10]'
check_Cc = '//*[@id="wid_46"]'
campo_corpo_clinico = '//*[@id="detail_5_container"]/div[7]/div[3]/div[2]/div/div'

#+++++================++====+++==============

for linha in range(2, len(sheet_selecionada['A']) +1):
    
#for linha in range(2,3):
    
    #pega a informação dentro da planilha
    pessoaF2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value
    cns2 = sheet_selecionada['C%s' % linha].value
    
    pessoaF = str(pessoaF2)
    nome = unidecode(str(nome2))
    cns = unidecode(str(cns2))
    
    #PREENCHE O CAMPO CODIGO COM O CODIGO DE PESSOA FISICA
    time.sleep(1)
    meuNavegador.find_element(By.XPATH, campo_codigo).clear()
    time.sleep(1)
    meuNavegador.find_element(By.XPATH, campo_codigo).send_keys(pessoaF)
    time.sleep(1)
    
    #CLICA NO BOTÃO FILTRAR
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_filtrar).click()
    time.sleep(1)
    

    #CLICA NO BOTÃO VER D
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_ver_D).click()
    time.sleep(1)
    
    #VERIFICA SE O CAMPO CORPO CLÍNICO ESTA MARCADO, CASO NÃO ESTEJA MARCA E SALVA, CASO ESTEJA FECHA OS DADOS
    time.sleep(1)
    check = meuNavegador.find_element(By.XPATH, check_Cc).is_selected()
    time.sleep(1)
    if check == False:
        meuNavegador.find_element(By.XPATH, campo_corpo_clinico).click()
        #CLICA EM SALVAR
        time.sleep(2)
        meuNavegador.find_element(By.XPATH, botao_salvar_D).click()
        time.sleep(1)
    else:
        #CLICA EM FECHAR
        time.sleep(2)
        meuNavegador.find_element(By.XPATH, botao_fechar_D).click()
        time.sleep(1)

    
    
    #CLICAR NO FUNIL FILTRO
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_funil_filtro).click()
    time.sleep(1)
    
    
    print('linha: ', linha)
    print('matricula: ',pessoaF)
    print('nome: ',nome)
    print('cns: ', cns)
    print('___________===============_________________=============__________\n')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nPreenchendo cns medico\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Preenchendo cns medico
#
# Inicio Data:  2022-07-07 - Hora:  18:14:23
# linha:  2
# matricula:  32810934
# nome:  Camila Marques Baesse
# cns:
# 702104773578793
# ___________===============_________________=============__________
#
# linha:  3
# matricula:  14088240
# nome:  Catharina Somerlate Franco Tomich
# cns:  703406298070813
# ___________===============_________________=============__________
#
# linha:  4
# matricula:  30689709
# nome:  DANIEL OLIVEIRA CONTI
# cns:  705002601370454
# ___________===============_________________=============__________
#
# linha:  5
# matricula:  6360169
# nome:  Deborah Nogueira Couto
# cns:  702803621312564
# ___________===============_________________=============__________
#
# linha:  6
# matricula:  32237235
# nome:  Denise Almeida Araujo Basso
# cns:  706204000702965
# ___________===============_________________=============__________
#
# linha:  7
# matricula:  32830063
# nome:  Diogo Ribeiro Borges Santos
# cns:  702809547785870
# ___________===============_________________=============__________
#
# linha:  8
# matricula:  31388400
# nome:  Elvio Antonio Gomes da Cunha
# cns:  709804059270998
# ___________===============_________________=============__________
#
# linha:  9
# matricula:  32237244
# nome:  Gabriela Pires de Araujo
# cns:  708404265532965
# ___________===============_________________=============__________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5248/2813912002.py in <module>
#      49
#      50     #CLICA NO BOTÃO FILTRAR
# ---> 51     time.sleep(2)
#      52     meuNavegador.find_element(By.XPATH, botao_filtrar).click()
#      53     time.sleep(1)
#
# KeyboardInterrupt:
