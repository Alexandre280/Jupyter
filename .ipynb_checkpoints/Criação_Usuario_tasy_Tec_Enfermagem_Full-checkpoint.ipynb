# %%
# test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time
from datetime import datetime

nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\Lista Tec Enfermagem Grace.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Tec Enfermagem Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Tec Enfermagem Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

for linha in range(57, len(sheet_selecionada['A']) +1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)

    #clica em adcionar novo usuario
    pagi.moveTo(806, 561)
    pagi.click()
    time.sleep(1)

    #encontra campo nome
    pagi.moveTo(940, 305)
    pagi.click()
    pagi.write(nome)
    time.sleep(1)
    
    #colocar senha para resetar em 180 dias
    pagi.moveTo(x=280, y=386) # encontrar campo para digatar a quantidade de dias
    time.sleep(0.5)
    pagi.click() #clica no campo
    pagi.write('180') #escreve a quantidade de dias
    time.sleep(0.5) 

    #rola scroll ate função para evolução/prescição
    pagi.moveTo(1558, 339)
    pagi.mouseDown(x=1558, y=480)
    pagi.mouseUp()
    time.sleep(1)

    #seleciona a função para evolução/prescição
    pagi.moveTo(1092, 586)
    pagi.click()
    pagi.write('tec')
    time.sleep(1)
    pagi.press('down')
    pagi.press('enter')
    time.sleep(1)

    #encontra botão salvar
    pagi.moveTo(1519, 775)
    pagi.click() #clicar no botão salvar

    #encontra botão de seleção
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    pagi.moveTo(118, 240) #encontra o botão perfis
    time.sleep(1)
    pagi.click() #clica no botão perfis
    time.sleep(1)

    #encontra botão copia de perfil
    pagi.moveTo(192, 199)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario
    pagi.moveTo(56, 289)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario ref
    pagi.moveTo(419, 302)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #escreve a matricula do usuario referencia tecnico enfermagem
    pagi.write('6323172')
    time.sleep(1)

    #marca perfil e setor
    pagi.moveTo(350, 396) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    pagi.moveTo(505, 399) #perfil
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(nome)
    time.sleep(1)
    
    #clicar em filtrar
    pagi.moveTo(1513, 344)
    pagi.click()
    time.sleep(1.5)
    

    #encontra o botão copiar
    pagi.moveTo(713, 357)
    pagi.mouseDown(button='left', x=713, y=745)
    pagi.mouseUp()
    time.sleep(1)
    pagi.moveTo(386, 758)
    time.sleep(1)
    pagi.click()

    #clicar em ok no final (pop-up)
    pagi.moveTo(x=938, y=552)
    time.sleep(2)
    pagi.click()
    time.sleep(2)
    
    #encontra botão de seleção / voltar para aba Usuario
    time.sleep(1)
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    pagi.moveTo(x=101, y=375)
    time.sleep(1)
    pagi.click() 
    
#--------------------------------------------------------|=Indo para Usúario filtrado=|-------------------------------------
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    pagi.click()
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    pagi.click()
    time.sleep(1)
    
#--------------------------------------------------------|=Gera senha=|-------------------------------------
    #gera senha
    #encontrar o botão gerar senha
    pagi.moveTo(x=1525, y=224) #encontra botão gerar senha
    pagi.click() #clica botão gerar senha
    time.sleep(1)
    pagi.moveTo(x=790, y=462)#encontra campo para digitar senha
    time.sleep(1)
    pagi.write('123tasy') #escreve a senha '123tasy'
    time.sleep(1)
    pagi.moveTo(x=940, y=597) # encontra botão OK
    time.sleep(1)
    pagi.click() #clica botão OK (confirmar criação de senha)
    time.sleep(1.5)
    pagi.moveTo(x=948, y=544) #encontrar botão ok senha gerada com sucesso
    time.sleep(1.5)
    pagi.click() #clica botão ok senha gerada com sucesso
    
#--------------------------------------------------------|=Indo para filtro icone na tela=|-------------------------------------
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(x=50, y=278) #move mouse no filtro "icone na tala"
    time.sleep(1)
    pagi.click() #clica no filtro "icone na tala"

#--------------------------------------------------------|=Printar o nome/matricula do usuario criado=|------------------
    print('linha: ', linha, 'matricula: ',matricula)
    print('nome: ', nome)
    print('___________===============_________________=============__________\n')
    
data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Tec Enfermagem Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Criação Usuario Tec Enfermagem Tasy
#
# Inicio Data:  2022-01-17 - Hora:  11:09:11
# linha:  57 matricula:  6322026
# nome:  PAULO SERGIO DE OLIVEIRA CARRIJO
# ___________===============_________________=============__________
#
# linha:  58 matricula:  6322301
# nome:  PERCILIANA DE REZENDE SILVA
# ___________===============_________________=============__________
#
# linha:  59 matricula:  6322619
# nome:  POLLIANNA AMARAL DA COSTA PEREIRA
# ___________===============_________________=============__________
#
# linha:  60 matricula:  6321303
# nome:  POLLYANNA APARECIDA RODRIGUES DE MOURA
# ___________===============_________________=============__________
#
# linha:  61 matricula:  6322173
# nome:  POLYANA LINA BATISTA
# ___________===============_________________=============__________
#
# linha:  62 matricula:  6322620
# nome:  PRISCILA FERREIRA ARAUJO MUSSI
# ___________===============_________________=============__________
#
# linha:  63 matricula:  6323350
# nome:  LUCIANA APARECIDA ALVES DE SOUZA
# ___________===============_________________=============__________
#
# linha:  64 matricula:  6323482
# nome:  LUCIMAR PEREIRA DO NASCIMENTO SOUSA TERNA
# ___________===============_________________=============__________
#
# linha:  65 matricula:  6323921
# nome:  MARGARETE APARECIDA SOARES
# ___________===============_________________=============__________
#
# linha:  66 matricula:  6323425
# nome:  MARIA APARECIDA GOMES DE SOUZA
# ___________===============_________________=============__________
#
# linha:  67 matricula:  6323573
# nome:  MARIA DO CEU FERNANDES DE LIMA
# ___________===============_________________=============__________
#
# linha:  68 matricula:  6322056
# nome:  MARIA JOSE MARTINS DE MELO
# ___________===============_________________=============__________
#
# linha:  69 matricula:  6323785
# nome:  MARIA ROSILANDIA DE OLIVEIRA ANTUNES
# ___________===============_________________=============__________
#
# linha:  70 matricula:  6323215
# nome:  MARILIA APARECIDA BATISTA
# ___________===============_________________=============__________
#
# linha:  71 matricula:  6323217
# nome:  MARLENE DE CRISTO
# ___________===============_________________=============__________
#
# linha:  72 matricula:  6324050
# nome:  MARTA PAULINO MACHADO
# ___________===============_________________=============__________
#
# linha:  73 matricula:  6323985
# nome:  MAYLSON OLIVEIRA DOS SANTOS
# ___________===============_________________=============__________
#
# linha:  74 matricula:  6323218
# nome:  MEIRE TEREZINHA DA SILVA OLIVEIRA
# ___________===============_________________=============__________
#
# linha:  75 matricula:  6322662
# nome:  MIRIAN APARECIDA DA SILVA
# ___________===============_________________=============__________
#
# linha:  76 matricula:  6323220
# nome:  MIRLA SANTOS DE MIRANDA
# ___________===============_________________=============__________
#
# linha:  77 matricula:  6324131
# nome:  NAYANE XAVIER DE OLIVEIRA
# ___________===============_________________=============__________
#
# linha:  78 matricula:  6323922
# nome:  NAYARA GERALDA BARBOSA AMANCIO
# ___________===============_________________=============__________
#
# linha:  79 matricula:  6323923
# nome:  NICASSIO BOSSUE LEMES MENEZES
# ___________===============_________________=============__________
#
# linha:  80 matricula:  6323484
# nome:  PATRICIA ANTUNES XAVIER SOUTO
# ___________===============_________________=============__________
#
# linha:  81 matricula:  6323811
# nome:  PATRICIA BATISTA DOS SANTOS ARAUJO
# ___________===============_________________=============__________
#
# linha:  82 matricula:  6323222
# nome:  PAULA RENATA DA SILVA SOARES
# ___________===============_________________=============__________
#
# linha:  83 matricula:  6323575
# nome:  POLYANA PRADO NASCIMENTO
# ___________===============_________________=============__________
#
# linha:  84 matricula:  6323223
# nome:  PRISCILLA CANDIDA RODRIGUES
# ___________===============_________________=============__________
#
# linha:  85 matricula:  6323224
# nome:  QUEZIA REGINA RABELO
# ___________===============_________________=============__________
#
# linha:  86 matricula:  6323736
# nome:  RAIANA PEREIRA DA SILVA
# ___________===============_________________=============__________
#
# linha:  87 matricula:  6323225
# nome:  RAQUEL SOARES DE OLIVEIRA
# ___________===============_________________=============__________
#
# linha:  88 matricula:  6323665
# nome:  RENATA DE PAULA MARQUES DA SILVA
# ___________===============_________________=============__________
#
# linha:  89 matricula:  6324164
# nome:  RENER MARTINS DE MOURA FILHO
# ___________===============_________________=============__________
#
# linha:  90 matricula:  6324132
# nome:  RENYSSE MUNIZ DA SILVA
# ___________===============_________________=============__________
#
#
# Criação Usuario Tec Enfermagem Tasy
#
# Finalizado Data:  2022-01-17 - Hora:  11:44:11
# 'OK'
