# %%
# test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time
from datetime import datetime


nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\medicos_pj.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Emfermeiro Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Medico Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

for linha in range(1, len(sheet_selecionada['A']) +1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))

    
    time.sleep(2)
    #encontra campo chapa
    pagi.moveTo(x=127, y=257)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(matricula)
    time.sleep(1)
    
    
    #clica campo gerar senha
    pagi.moveTo(x=296, y=250)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #pegar senha gerada
    pagi.moveTo(x=972, y=370)
    time.sleep(1)
    pagi.doubleClick()
    time.sleep(1)
    pagi.hotkey
    
    //*[@id="lpresult"]/div[2]/p
    
    
    
    
    
    print('linha: ', linha)
    print('matricula: ',matricula)
    print('nome: ', nome)
    print('nome: ', cpf)
    print('___________===============_________________=============__________\n')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Emfermeiro Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
#   File "C:\Users\6324102\AppData\Local\Temp/ipykernel_3712/246011100.py", line 58
#     //*[@id="lpresult"]/div[2]/p
#     ^
# SyntaxError: invalid syntax

# %%
pagi.position()
# Out:
# Point(x=972, y=370)

# %%
# test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time
from datetime import datetime


nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\medicos_pj.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Emfermeiro Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Medico Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

for linha in range(1, len(sheet_selecionada['A']) +1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['B%s' % linha].value
    nome2 = sheet_selecionada['A%s' % linha].value
    cpf2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    cpf = str(cpf2)
    
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(x=47, y=278)
    time.sleep(1.5)
    pagi.click()
    
    #campo usuario
    pagi.moveTo(x=415, y=246)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1)
    pagi.hotkey('ctrlleft', 'a')
    time.sleep(0.5)
    pagi.press('backspace')
    time.sleep(1)
    pagi.write(matricula)
    time.sleep(1)
    
    #encontra campo filtrar
    pagi.moveTo(418, 775)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1)
    
    #ver usuario 
    pagi.moveTo(x=1542, y=222)
    time.sleep(1.5)
    pagi.click()
    time.sleep(3)
    
    #encontrar pessoa
    pagi.moveTo(x=1530, y=480)
    time.sleep(1)
    pagi.click()
    time.sleep(2)
    
    #alterar campo para CPF
    pagi.moveTo(x=322, y=245)
    time.sleep(1)
    pagi.click()
    time.sleep(1.5)
    pagi.press('n')
    time.sleep(1.5)
    pagi.press('down')
    time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1.5)
    
    #escrever cpf
    pagi.moveTo(x=272, y=332)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(cpf)
    time.sleep(1)
    
    #filtrar / confirmar pessoa
    pagi.moveTo(x=464, y=765)
    time.sleep(1)
    pagi.click()
    time.sleep(2)
    pagi.moveTo(x=1511, y=763) #encontra botão OK
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #salvar
    pagi.moveTo(x=1515, y=766)
    time.sleep(1)
    pagi.click()
    time.sleep(2)
    
    print('linha: ', linha)
    print('matricula: ',matricula)
    print('nome: ', nome)
    print('nome: ', cpf)
    print('___________===============_________________=============__________\n')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Emfermeiro Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Criação Usuario Medico Tasy
#
# Inicio Data:  2022-06-27 - Hora:  23:32:33
# linha:  1
# matricula:  75649233691
# nome:  Jorge Fernando Mamede Moreira
# nome:  75649233691
# ___________===============_________________=============__________
#
# linha:  2
# matricula:  4323227604
# nome:  Vivalde Faria Lobato Neto
# nome:  4323227604
# ___________===============_________________=============__________
#
# linha:  3
# matricula:  46957804100
# nome:  Saulo Rodrigues Junior
# nome:  46957804100
# ___________===============_________________=============__________
#
# linha:  4
# matricula:  4462800621
# nome:  Martha Artiaga Cunha Porto
# nome:  4462800621
# ___________===============_________________=============__________
#
# linha:  5
# matricula:  99921987615
# nome:  Oscari Bruno
# nome:  99921987615
# ___________===============_________________=============__________
#
# linha:  6
# matricula:  75649730644
# nome:  Regina Maria de Souza Ferreira
# nome:  75649730644
# ___________===============_________________=============__________
#
# linha:  7
# matricula:  2360500104
# nome:  Nilson Abreu
# nome:  2360500104
# ___________===============_________________=============__________
#
# linha:  8
# matricula:  6633052602
# nome:  Luciane Borges Marson
# nome:  6633052602
# ___________===============_________________=============__________
#
# linha:  9
# matricula:  6494611699
# nome:  Bruna Pires Guerra de Andrade
# nome:  6494611699
# ___________===============_________________=============__________
#
# linha:  10
# matricula:  10453825644
# nome:  Ana Flavia Yanosteach
# nome:  10453825644
# ___________===============_________________=============__________
#
# linha:  11
# matricula:  84900733687
# nome:  Claudio Ribeiro da Cunha
# nome:  84900733687
# ___________===============_________________=============__________
#
# linha:  12
# matricula:  21397242833
# nome:  Daniel Oliveira de Conti
# nome:  21397242833
# ___________===============_________________=============__________
#
# linha:  13
# matricula:  866400308668
# nome:  Paulo Cesar Santos
# nome:  866400308668
# ___________===============_________________=============__________
#
# linha:  14
# matricula:  86623435891
# nome:  Helio Antonio Fabri
# nome:  86623435891
# ___________===============_________________=============__________
#
# linha:  15
# matricula:  96661976691
# nome:  Daladie Rodrigues Parreira
# nome:  96661976691
# ___________===============_________________=============__________
#
# linha:  16
# matricula:  55852157368
# nome:  Raelson de Lima Batista
# nome:  55852157368
# ___________===============_________________=============__________
#
# linha:  17
# matricula:  6751510667
# nome:  Leonardo Ferreira de Faria
# nome:  6751510667
# ___________===============_________________=============__________
#
# linha:  18
# matricula:  9409888603
# nome:  Thiago de Oliveira Lemos Lima
# nome:  9409888603
# ___________===============_________________=============__________
#
# linha:  19
# matricula:  7621415657
# nome:  Marcelo Gomes de Almeida
# nome:  7621415657
# ___________===============_________________=============__________
#
# linha:  20
# matricula:  39427269634
# nome:  Marcelo Batista Chiovato dos Santos
# nome:  39427269634
# ___________===============_________________=============__________
#
# linha:  21
# matricula:  91119839653
# nome:  Maykell Queiroz dos Reis
# nome:  91119839653
# ___________===============_________________=============__________
#
# linha:  22
# matricula:  39360504653
# nome:  Isac Alor Dias
# nome:  39360504653
# ___________===============_________________=============__________
#
# linha:  23
# matricula:  74804616071
# nome:  Sandro Diego Beraldo
# nome:  74804616071
# ___________===============_________________=============__________
#
# linha:  24
# matricula:  8600569613
# nome:  Victor do Couto Rosa Conesa Jordao
# nome:  8600569613
# ___________===============_________________=============__________
#
#
# Criação Usuario Emfermeiro Tasy
#
# Finalizado Data:  2022-06-27 - Hora:  23:48:26
# 'OK'

# %%
pagi.position()
# Out:
# Point(x=1515, y=766)

# %%
from selenium import webdriver

abrirNavegador = webdriver.Chrome()

abrirNavegador.get("http://site.spdmafiliadas.org.br/gerarsenham/vcadastro3.php")

# %%
from selenium import webdriver as opções_selenium_aula
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as pagi
from openpyxl import load_workbook
import os
from unidecode import unidecode
import time
from datetime import datetime


nome_caminho_arquivo = "C:\\Users\\6324102\\Documents\\Python Scripts\\Jupyter\\lista_usuarios_tasy\\teste_senha_medicos_ead2.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Emfermeiro Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Medico Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

meuNavegador = opções_selenium_aula.Chrome()
meuNavegador.get('http://site.spdmafiliadas.org.br/gerarsenham/vcadastro3.php')

#tempo de espera para abrir o site
pagi.sleep(8)

for linha in range(2, len(sheet_selecionada['A']) +1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    #nome2 = sheet_selecionada['B%s' % linha].value
    #senha2 = sheet_selecionada['C%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    #nome = unidecode(str(nome2))
    #senha = str(cpf2)

    #digita a matricula no campo chapa
    meuNavegador.find_element(By.NAME, 'busca_cpf').send_keys(matricula)

    #tempo de espera para escrever
    pagi.sleep(3)

    #digita a matricula no campo chapa
    meuNavegador.find_element(By.NAME, 'busca_cpf').send_keys(Keys.RETURN)

    #tempo de espera para escrever
    pagi.sleep(3)


    senha = meuNavegador.find_elements(By.XPATH, '//*[@id="lpresult"]/div[2]/p')
    campo = []
    for item in senha:
        campo = item.text
        print(item.text)

    encontra_senha = campo.find('SENHA')
    pega_senha = campo[encontra_senha+7:]
    pega_senha = str(pega_senha)
    
    sheet_selecionada.write('C' + str(linha), pega_senha)
    
    print('linha: ', linha)
    print('matricula: ',matricula)
    print('nome: ', nome)
    print('senha: ', pega_senha)
    print('___________===============_________________=============__________\n')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Emfermeiro Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Criação Usuario Medico Tasy
#
# Inicio Data:  2022-07-13 - Hora:  17:09:05
# NOME COMPLETO:RODRIGO SALES INOCENTE - SENHA: d0b115
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 30>()
#      65 pega_senha = campo[encontra_senha+7:]
#      66 pega_senha = str(pega_senha)
# ---> 68 sheet_selecionada.write('C' + str(linha), pega_senha)
#      70 print('linha: ', linha)
#      71 print('matricula: ',matricula)
#
# AttributeError: 'Worksheet' object has no attribute 'write'

# %%
print(campo)
print(campo.find('SENHA'))
encontra_senha = campo.find('SENHA')
pega_senha = campo[pega_senha+7:]
print(pega_senha)
# Out:
# NOME COMPLETO:RONALDO SOARES FARIA - SENHA: c07d8e
# 37
# c07d8e

# %%
    #digita a matricula no campo chapa
    meuNavegador.find_element(By.NAME, 'busca_cpf').send_keys(matricula)

    #tempo de espera para escrever
    pagi.sleep(3)

    #digita a matricula no campo chapa
    meuNavegador.find_element(By.NAME, 'busca_cpf').send_keys(Keys.RETURN)

    #tempo de espera para escrever
    pagi.sleep(3)


    senha = meuNavegador.find_elements(By.XPATH, '//*[@id="lpresult"]/div[2]/p')
    campo = []
    for item in senha:
        campo = item.text
        print(item.text)

    encontra_senha = campo.find('SENHA')
    pega_senha = campo[encontra_senha+7:]
    pega_senha = str(pega_senha)
    print('senha do caboco: {}'.format(pega_senha))
# Out:
# NOME COMPLETO:RODRIGO SALES INOCENTE - SENHA: 75610a
# senha do caboco: 75610a

# %%
sheet_selecionada.write(linha, 'C', pega_senha)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7336/1970460883.py in <module>
# ----> 1 sheet_selecionada.write(linha, 'C', pega_senha)
#
# AttributeError: 'Worksheet' object has no attribute 'write'

# %%
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in c:\programdata\anaconda3\lib\site-packages (3.0.1)

# %%
import xlsxwriter
 
arquivo = 'C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\teste_senha_medicos_ead.xlsx'
planilha_criada = xlsxwriter.Workbook(arquivo)
sheet1 = planilha_criada.add_worksheet()

sheet1.write('C' + str(linha), pega_senha)
# Out:
# 0

# %%
from selenium import webdriver as opções_selenium_aula
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as pagi
from openpyxl import load_workbook
import os
from unidecode import unidecode
import time
from datetime import datetime
import xlsxwriter


nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\medicos_ead.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Emfermeiro Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Medico Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

meuNavegador = opções_selenium_aula.Chrome()
meuNavegador.get('http://site.spdmafiliadas.org.br/gerarsenham/vcadastro3.php')

#tempo de espera para abrir o site
pagi.sleep(8)


arquivo = 'C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\\medicos_ead_senha.xlsx'
planilha_criada = xlsxwriter.Workbook(arquivo)
sheet1 = planilha_criada.add_worksheet('Planilha1')

for linha in range(2, len(sheet_selecionada['A']) +1):
#for linha in range(2, 6):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value
    #senha2 = sheet_selecionada['C%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    #senha = str(cpf2)

    #digita a matricula no campo chapa
    meuNavegador.find_element(By.NAME, 'busca_cpf').send_keys(matricula)

    #tempo de espera para escrever
    pagi.sleep(3)

    #digita a matricula no campo chapa
    meuNavegador.find_element(By.NAME, 'busca_cpf').send_keys(Keys.RETURN)

    #tempo de espera para escrever
    pagi.sleep(3)


    senha = meuNavegador.find_elements(By.XPATH, '//*[@id="lpresult"]/div[2]/p')
    campo = []
    for item in senha:
        campo = item.text
        print(item.text)

    encontra_senha = campo.find('SENHA')
    pega_senha = campo[encontra_senha+7:]
    pega_senha = str(pega_senha)
    
    sheet1.write('A' + str(linha), matricula)
    sheet1.write('B' + str(linha), nome)
    sheet1.write('C' + str(linha), pega_senha)

    print('\nlinha: ', linha)
    print('matricula: ',matricula)
    print('nome: ', nome)
    print('senha: ', pega_senha)
    print('___________===============_________________=============__________\n')
    
planilha_criada.close()
#os.startfile(arquivo)
data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Emfermeiro Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')

# %%
    senha = meuNavegador.find_elements(By.XPATH, '//*[@id="lpresult"]/div[2]/p')
    campo = []
    for item in senha:
        campo = item.text
        print(item.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 senha = meuNavegador.find_elements(By.XPATH, '//*[@id="lpresult"]/div[2]/p')
#       2 campo = []
#       3 for item in senha:
#
# NameError: name 'meuNavegador' is not defined
