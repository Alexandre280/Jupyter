# %% [markdown]
# # ABRE NAVEGADOR E NO TASY

# %%
from selenium import webdriver as opções_selenium_aula
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as pagi
from openpyxl import load_workbook
import os
from unidecode import unidecode
import time
from datetime import datetime

meuNavegador = opções_selenium_aula.Chrome()
meuNavegador.get('http://tasyweb.spdmafiliadas.org.br/#/')

# %% [markdown]
# # EXECUTA PROCEDIMENTO NO TASY

# %%
#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time
from datetime import datetime

nome_caminho_arquivo = "C:\\Users\\6324102\\Documents\\GitHub\\teste1.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Tec Enfermagem Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Tec Enfermagem Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

#+++++====================++++==============CAMPOS TASY
campo_usuario_f = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[1]/tasy-wfilter/div/tasy-wmdetail/div[2]/div[3]/form/div/div[1]/div[2]/div[2]/tasy-wtextbox/div/div/input'
botao_filtrar = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[1]/tasy-wfilter/div/div[2]/div/button'
botão_funil_filtro = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/tasy-wlabel'
botao_ver = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[2]/tasy-handlebar-new/div/div[1]/div/button[9]/span'
campo_do_usuario = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[5]/div[1]/w-datagrid/div[3]/div/div[5]/div[3]/div'
campo_funcionario_s = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/div[2]/tasy-wmdetail/div[2]/div[3]/form/div/div[10]/div[2]/div[2]/tasy-listbox/div'
atributo_tec_enf = '/html/body/div[4]/div[2]/div[1]/div/a[22]/span'
botao_salvar = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/div[2]/tasy-wmdetail/div[2]/div[3]/form/w-persistence-action-bar/w-persistence-action-bar-button[1]/tasy-wbutton/div'
botao_filtrar2 = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[4]/tasy-wlabel'
botao_fechar = '/html/body/div[1]/tasy-corsisf1/div/w-mainlayout/div/div/feature-instance/corsisfo/div/tasypopupmenu/div/div/div/div/div/div/tasypopupmenu/tasy-wdbpanel/div/div[2]/div[2]/tasy-handlebar-new/div/div[1]/div/button[10]/span'




for linha in range(426, len(sheet_selecionada['A']) +1):
    
    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['C%s' % linha].value
    cargo2 = sheet_selecionada['D%s' % linha].value
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    cargo = unidecode(str(cargo2))
    
    #PREENCHE O CAMPO USUARIO COM A MATRICULA DO COLABORADOR
    time.sleep(1)
    meuNavegador.find_element(By.XPATH, campo_usuario_f).clear()
    time.sleep(1)
    meuNavegador.find_element(By.XPATH, campo_usuario_f).send_keys(matricula)
    time.sleep(1)
    
    #CLICA NO BOTÃO FILTRAR
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_filtrar).click()
    time.sleep(1)
    
    #VERIFICA SE O BOTÃO "VER" ESTA NA TELA
    if meuNavegador.find_element(By.XPATH, botao_ver).is_displayed() == False:

        #CLICAR NO FUNIL FILTRO
        time.sleep(2)
        meuNavegador.find_element(By.XPATH, botão_funil_filtro).click()
        time.sleep(1)
       
        print('Colaborador não cadastrado')
        print('linha: ', linha)
        print('matricula: ',matricula)
        print('nome: ',nome)
        print('cargo: ', cargo)
        print('___________===============_________________=============__________\n')
        
        dict_nao_cadastrados[linha] = [(matricula, nome, cargo)]
        continue
    
    #CLICA NO BOTÃO VER
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_ver).click()
    time.sleep(1)
    
    #CLICA CAMPO  "FUNÇÃO PARA EVOLUÇÃO / PRESCRIÇÃO"
    #SE O CAMPO JA ESTIVER COMO TÉCNICO DE ENFERMAGEM FECHAR E PASSA PARA O PROXIMO
    if meuNavegador.find_element(By.XPATH, campo_funcionario_s).text == 'Técnico de enfermagem':
        time.sleep(1)
        meuNavegador.find_element(By.XPATH, botao_fechar).click()
        time.sleep(1)
        
        #CLICAR NO FUNIL FILTRO
        time.sleep(2)
        meuNavegador.find_element(By.XPATH, botao_filtrar2).click()
        time.sleep(1)
        continue
        
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, campo_funcionario_s).click()
    time.sleep(1)
    
    #CLICA NA OPÇÃO TÉCNICO DE ENFERMAGEM
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, atributo_tec_enf).click()
    time.sleep(1)
    
    #CLICA EM SALVAR
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_salvar).click()
    time.sleep(1)
    
    #CLICAR NO FUNIL FILTRO
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_filtrar2).click()
    time.sleep(1)
    
#--------------------------------------------------------|=Printar o nome/matricula do usuario criado=|------------------
    print('linha: ', linha) 
    print('matricula: ',matricula)
    print('nome: ', nome)
    print('cargo: ', cargo)
    print('___________===============_________________=============__________\n')
    
data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Tec Enfermagem Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Criação Usuario Tec Enfermagem Tasy
#
# Inicio Data:  2022-09-30 - Hora:  15:54:20
# linha:  427
# matricula:  6322611
# nome:  1- Catarina do Socorro do E Santo Mota
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  428
# matricula:  6321851
# nome:  2- Silma dos Reis Mendes
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  429
# matricula:  6322620
# nome:  3- Priscila Ferreira Araujo Mussi
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  430
# matricula:  6324341
# nome:  4- Liliana Vieira Martins
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  431
# matricula:  6322481
# nome:  3- Lidiane Oliveira Santos
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  432
# matricula:  6323946
# nome:  4- Debora dos Santos Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  433
# matricula:  6321082
# nome:  1- Janaina Clementino Pereira
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  434
# matricula:  6321488
# nome:  2- Ana Paula Cochak
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  435
# matricula:  6321056
# nome:  1- Thuanny Fernandes Araujo
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  436
# matricula:  6320413
# nome:  2- Neire de Freitas Mendonca
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  437
# matricula:  6321746
# nome:  1- Nubia Rodrigues Mamede Carrijo
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  438
# matricula:  6321924
# nome:  2- Ana Lucia Soares de Oliveira Ramos
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  439
# matricula:  6322134
# nome:  3- Heloisa Helena Carrijo Ramos
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  440
# matricula:  6320982
# nome:  Erica Cristina Silva Moura
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  442
# matricula:  6321199
# nome:  1- Carlos Eduardo de Oliveira
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  443
# matricula:  6322795
# nome:  1- Helio Rubens Lara
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  444
# matricula:  6322947
# nome:  2- Uander Rodrigues da Cunha
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  445
# matricula:  6322408
# nome:  3- Guilherme Fagundes Vieira
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  446
# matricula:  6322575
# nome:  1- Aline Marques Parreira de Moura
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  447
# matricula:  6323622
# nome:  Dirleine de Mascarenhas Leite
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  448
# matricula:  6322937
# nome:  2- Ian Elias Rosa
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  449
# matricula:  6322581
# nome:  3- Lucimar Bernardo da Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  450
# matricula:  6322705
# nome:  4- Fabiane Souza Ramos
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  451
# matricula:  6323161
# nome:  5- Bruno Luiz de Oliveira Cunha
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  452
# matricula:  6322480
# nome:  1- Jacqueline Duarte dos Reis
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  453
# matricula:  6322767
# nome:  2- Andressa de Oliveira Santos
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  454
# matricula:  6320680
# nome:  3- Roseli Marcia de Souza
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  455
# matricula:  6321108
# nome:  4- Leonel Ferreira Andrade
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  456
# matricula:  6323591
# nome:  5- Vivian Aparecida Pimenta Santos
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  457
# matricula:  6323105
# nome:  1- Juliana de Oliveira Queiroz
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  458
# matricula:  6322939
# nome:  2- Jessica Messias Nonato
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  459
# matricula:  6320672
# nome:  3- Kenia Maria Mendes Cordeiro
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  460
# matricula:  6323521
# nome:  4- Lorena Cunha Bueno
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  461
# matricula:  6322240
# nome:  5- Edilene Oliveira da Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  462
# matricula:  6321417
# nome:  1- Mauro Moreira Maciel
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  463
# matricula:  6322085
# nome:  2- Eleias Marques Fernandes
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  464
# matricula:  6324389
# nome:  3- Marco da Silva Felipe
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  465
# matricula:  6320851
# nome:  4- Claudineia Goncalves
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  466
# matricula:  6324077
# nome:  5- Fabiana Cristina Vitor
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  467
# matricula:  6321061
# nome:  1- Marilia Aparecida de Souza
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  468
# matricula:  6322948
# nome:  2- Valdirene Kelen de Andrade
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  469
# matricula:  6323159
# nome:  3- Thauane Pamela Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  470
# matricula:  6321250
# nome:  4- Sabrina Peixoto
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  471
# matricula:  6320558
# nome:  Aparecida Sant'ana Goncalves
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  472
# matricula:  6320596
# nome:  5- Adriana Vaz Soares
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  473
# matricula:  6322617
# nome:  6- Nayara Cristina Pereira Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  474
# matricula:  6322709
# nome:  7- Juliana Caetano de Miranda
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  475
# matricula:  6322585
# nome:  8- Vanessa Raphaela Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  476
# matricula:  6322938
# nome:  2- Ivone de Sousa Almeida
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  477
# matricula:  6323480
# nome:  3- Leidiane Dantas Silva
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  478
# matricula:  6323084
# nome:  2- Francielle Resende de La Fuentes
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  479
# matricula:  6320876
# nome:  3- Juliene Gomes de Oliveira
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  481
# matricula:  6320670
# nome:  2- Elisangela Aparecida Pacifico
# cargo:  TE
# ___________===============_________________=============__________
#
# linha:  482
# matricula:  6320848
# nome:  3- Maria Claret Campos
# cargo:  TE
# ___________===============_________________=============__________
#
#
# Criação Usuario Tec Enfermagem Tasy
#
# Finalizado Data:  2022-09-30 - Hora:  16:15:16
# 'OK'

# %%
#INICIALIZANDO O DICIONARIO ONDE IRÁ FICAR OS USUARIOS NÃO CADASTRADOS
dict_nao_cadastrados = {}

# %%
dict_nao_cadastrados
# Out:
# {}

# %%
matricula
# Out:
# '6323321'

# %%
meuNavegador.find_element(By.XPATH, campo_funcionario_s).text
# Out:
# 'Técnico de enfermagem'
