# %% [markdown]
# # ABRE NAVEGADOR NO GLPI

# %%
from selenium import webdriver as opções_selenium_aula
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as pagi
from openpyxl import load_workbook
import os
from unidecode import unidecode
import time
from datetime import datetime

meuNavegador = opções_selenium_aula.Chrome()
meuNavegador.get("http://centralti.spdmafiliadas.org.br/front/central.php")

# %% [markdown]
# # EXECUTA PROCEDIMENTO NO TASY

# %%
campo_chamado = '/html/body/div[4]/div/form[2]/div/table/tbody/tr[1]/td[3]4'

while meuNavegador.find_element(By.XPATH, campo_chamado).is_displayed():

for linha in range(2, len(sheet_selecionada['A']) +1):
    
#for linha in range(2,3):
    
    #pega a informação dentro da planilha
    pessoaF2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value
    cns2 = sheet_selecionada['C%s' % linha].value
    
    pessoaF = str(pessoaF2)
    nome = unidecode(str(nome2))
    cns = unidecode(str(cns2))
    
    #PREENCHE O CAMPO CODIGO COM O CODIGO DE PESSOA FISICA
    time.sleep(1)
    meuNavegador.find_element(By.XPATH, campo_codigo).clear()
    time.sleep(1)
    meuNavegador.find_element(By.XPATH, campo_codigo).send_keys(pessoaF)
    time.sleep(1)
    
    #CLICA NO BOTÃO FILTRAR
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_filtrar).click()
    time.sleep(1)
    

    #CLICA NO BOTÃO VER D
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_ver_D).click()
    time.sleep(1)
    
    #VERIFICA SE O CAMPO CORPO CLÍNICO ESTA MARCADO, CASO NÃO ESTEJA MARCA E SALVA, CASO ESTEJA FECHA OS DADOS
    time.sleep(1)
    check = meuNavegador.find_element(By.XPATH, check_Cc).is_selected()
    time.sleep(1)
    if check == False:
        meuNavegador.find_element(By.XPATH, campo_corpo_clinico).click()
        #CLICA EM SALVAR
        time.sleep(2)
        meuNavegador.find_element(By.XPATH, botao_salvar_D).click()
        time.sleep(1)
    else:
        #CLICA EM FECHAR
        time.sleep(2)
        meuNavegador.find_element(By.XPATH, botao_fechar_D).click()
        time.sleep(1)

    
    
    #CLICAR NO FUNIL FILTRO
    time.sleep(2)
    meuNavegador.find_element(By.XPATH, botao_funil_filtro).click()
    time.sleep(1)
    
    
    print('linha: ', linha)
    print('matricula: ',pessoaF)
    print('nome: ',nome)
    print('cns: ', cns)
    print('___________===============_________________=============__________\n')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nPreenchendo cns medico\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Preenchendo cns medico
#
# Inicio Data:  2022-07-07 - Hora:  18:14:23
# linha:  2
# matricula:  32810934
# nome:  Camila Marques Baesse
# cns:
# 702104773578793
# ___________===============_________________=============__________
#
# linha:  3
# matricula:  14088240
# nome:  Catharina Somerlate Franco Tomich
# cns:  703406298070813
# ___________===============_________________=============__________
#
# linha:  4
# matricula:  30689709
# nome:  DANIEL OLIVEIRA CONTI
# cns:  705002601370454
# ___________===============_________________=============__________
#
# linha:  5
# matricula:  6360169
# nome:  Deborah Nogueira Couto
# cns:  702803621312564
# ___________===============_________________=============__________
#
# linha:  6
# matricula:  32237235
# nome:  Denise Almeida Araujo Basso
# cns:  706204000702965
# ___________===============_________________=============__________
#
# linha:  7
# matricula:  32830063
# nome:  Diogo Ribeiro Borges Santos
# cns:  702809547785870
# ...

# %%
campo_chamado = '/html/body/div[4]/div[2]/form[2]/div/table/tbody/tr[1]'
campo_processando_chamado = '/html/body/div[4]/div[2]/div[2]/ul/li[2]/a'
campo_solucao = '//*[@id="ui-tabs-2"]/div/div[1]/ul/li'
campo_select_tipo_chamado = '//*[@id="select2-drop"]'
campo_solucao_padrao = '//*[@id="select2-result-label-6"]'
campo_salvar = '/html/body/div[4]/div[2]/div[2]/div[2]/div/div[2]/form/div/table/tbody/tr[6]/td/input[1]'
campo_chamado = '/html/body/div[1]/div[3]/ul/li[3]'

contador = 0

while meuNavegador.find_element(By.XPATH, campo_chamado).is_displayed() and contador < 3:
    time.sleep(1)
    
    #clicar no chamado
    pagi.moveTo(x=212, y=510)
    time.sleep(1)
    pagi.click()
    time.sleep(2)
#     meuNavegador.find_element(By.XPATH, campo_chamado).click()
#     time.sleep(1)
    
    #clicar no campo processando chamado
    meuNavegador.find_element(By.XPATH, campo_processando_chamado).click()
    time.sleep(2)
    
    #clicar no campo solução
    meuNavegador.find_element(By.XPATH, campo_solucao).click()
    time.sleep(2)
    
    #clicar no campo solução padrão 1
#     meuNavegador.find_element(By.XPATH, campo_solucao_padrao).click()
#     time.sleep(2)
    
    #clicar em salvar o texto padrão solucionado
    meuNavegador.find_element(By.XPATH, campo_salvar).click()
    time.sleep(2)
    
    #clicar no campo chamado para voltar para a lista de chamados
    meuNavegador.find_element(By.XPATH, campo_chamado).click()
    time.sleep(2)
    
    contador += 1
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [32], in <cell line: 11>()
#      18     time.sleep(2)
#      19 #     meuNavegador.find_element(By.XPATH, campo_chamado).click()
#      20 #     time.sleep(1)
#      21
#      22     #clicar no campo processando chamado
# ---> 23     meuNavegador.find_element(By.XPATH, campo_processando_chamado).click()
#      24     time.sleep(2)
#      26     #clicar no campo solução
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:857, in WebDriver.find_element(self, by, value)
#     854     by = By.CSS_SELECTOR
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
# ...

# %%
pagi.position()
# Out:
# Point(x=445, y=339)

# %%
salvar = '/html/body/div[4]/div[2]/div[2]/div[2]/div/div[2]/form/div/table/tbody/tr[6]/td/input[1]'

contador = 0

while meuNavegador.find_element(By.XPATH, campo_chamado).is_displayed() and contador < 3:
    time.sleep(1)
    
    #clica no chamado
    pagi.moveTo(x=214, y=532)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no botão chamado
    pagi.moveTo(x=152, y=261)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no botão para atribuir o chamado para o meu nome
    pagi.moveTo(x=1277, y=647)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no botão processando chamado
    pagi.moveTo(x=183, y=290)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no botão solução
    pagi.moveTo(x=704, y=296)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no select para abrir a lista de soluções (texto prontos)
    pagi.moveTo(x=601, y=381)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no botão solução padrão 1
    pagi.moveTo(x=644, y=442)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica no scroll para descer a pagina
    pagi.moveTo(x=1591, y=636)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    
    #clica salvar texto de solução
    meuNavegador.find_element(By.NAME, "update").click()
    time.sleep(2)
#     pagi.moveTo(x=887, y=536)
#     time.sleep(1)
#     pagi.click()
#     time.sleep(1)
    
    #clica no botão chamados para ir para a lista de chamados
    pagi.moveTo(x=226, y=152)
    time.sleep(1)
    pagi.click()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [69], in <cell line: 5>()
#      54     time.sleep(1)
#      56     #clica salvar texto de solução
# ---> 57     meuNavegador.find_element(By.NAME, "update").click()
#      58     time.sleep(2)
#      59 #     pagi.moveTo(x=887, y=536)
#      60 #     time.sleep(1)
#      61 #     pagi.click()
#      62 #     time.sleep(1)
#      63
#      64     #clica no botão chamados para ir para a lista de chamados
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:857, in WebDriver.find_element(self, by, value)
#     854     by = By.CSS_SELECTOR
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# ...

# %%
    #clica no botão chamados para ir para a lista de chamados
    pagi.moveTo(x=226, y=152)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

# %%
contador = 0
while contador < 1850:
    #clica no botão chamados para ir para a lista de chamados
    pagi.moveTo(x=445, y=339)
    time.sleep(0.5)
    pagi.click()
    time.sleep(0.5)
    pagi.press('delete')
    time.sleep(0.5)
    contador +=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [73], in <cell line: 2>()
#       7 time.sleep(0.5)
#       8 pagi.press('delete')
# ----> 9 time.sleep(0.5)
#      10 contador +=1
#
# KeyboardInterrupt:
