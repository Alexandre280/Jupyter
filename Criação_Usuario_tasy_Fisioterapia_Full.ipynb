# %%
# test para finalizar

#criação usuario tasy codigo teste

from openpyxl import load_workbook
import os
from unidecode import unidecode
import pyautogui as pagi
import time
from datetime import datetime


nome_caminho_arquivo = "C:\\Users\\6324102\Documents\Alexandre\PYTHON AUTOMATIZAÇÃO\Jupyter\lista_usuarios_tasy\\Fisioterapia_criacao_usuario.xlsx"
planilha_aberta = load_workbook(filename = nome_caminho_arquivo)

#seleciona a aba que tem as informações a serem passadas para o formulario
sheet_selecionada = planilha_aberta['Planilha1']

pagi.alert('Criação Usuario Emfermeiro Tasy')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('Criação Usuario Medico Tasy\n\nInicio', 'Data: ', data, '- Hora: ', hora)

for linha in range(16, len(sheet_selecionada['A']) +1):

    #pega a informação dentro da planilha
    matricula2 = sheet_selecionada['A%s' % linha].value
    nome2 = sheet_selecionada['B%s' % linha].value

    #escreve a informação na tela
    #print(matricula)
    #print(unidecode(str(nome)))
    
    matricula = str(matricula2)
    nome = unidecode(str(nome2))
    
    time.sleep(2)
    #encontra campo usuario
    pagi.moveTo(411, 244)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1)

    #clica em adcionar novo usuario
    pagi.moveTo(806, 561)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1)

    #encontra campo nome
    pagi.moveTo(940, 305)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write(nome)
    time.sleep(1)
    
    #colocar senha para resetar em 180 dias
    pagi.moveTo(x=280, y=386) # encontrar campo para digatar a quantidade de dias
    time.sleep(0.5)
    pagi.click() #clica no campo
    pagi.write('180') #escreve a quantidade de dias
    time.sleep(0.5)
    
    #colocar campo setor
    pagi.moveTo(x=167, y=460) # encontrar campo setor
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write('fisio') #colocar Fisioterapia / Reabilitação
    time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1)

        #rola scroll ate função para evolução/prescição
    pagi.moveTo(1558, 339)
    time.sleep(1.5)
    pagi.mouseDown(x=1558, y=480)
    time.sleep(1.5)
    pagi.mouseUp()
    time.sleep(1)

    #seleciona a função para evolução/prescição
    pagi.moveTo(1092, 586)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write('fisio')
    time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1)

    #rola scroll ate campo Classe Profissional
    pagi.moveTo(x=1553, y=659)# move mouse
    time.sleep(1.5)
    pagi.click() # desce scroll
    time.sleep(1.5)
    pagi.moveTo(x=1376, y=397)# encontra compo Classe Profissional
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write('fisio')
    time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1)

    #encontra botão salvar
    pagi.moveTo(1519, 775)
    time.sleep(1.5)
    pagi.click() #clicar no botão salvar
    time.sleep(2.5)

    #encontra botão de seleção
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    time.sleep(1.5)
    pagi.moveTo(118, 240) #encontra o botão perfis
    time.sleep(1)
    pagi.click() #clica no botão perfis
    time.sleep(1)

    #encontra botão copia de perfil
    pagi.moveTo(192, 199)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario
    pagi.moveTo(56, 289)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra botão usuario ref
    pagi.moveTo(419, 302)
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #escreve a matricula do usuario referencia tecnico enfermagem
    pagi.write('6322198') #usuario referencia enfermeiro
    time.sleep(1)

    #marca perfil e setor
    pagi.moveTo(350, 396) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    pagi.moveTo(505, 399) #perfil
    time.sleep(1)
    pagi.click()
    time.sleep(1)


    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)

    #encontra Nome Completo
    pagi.moveTo(953, 289) #setor
    time.sleep(1)
    pagi.click()
    time.sleep(1)
    pagi.write(nome)
    time.sleep(1)
    
    #clicar em filtrar
    pagi.moveTo(1513, 344)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    

    #encontra o botão copiar
    pagi.moveTo(713, 357)
    time.sleep(1.5)
    pagi.mouseDown(button='left', x=713, y=745)
    time.sleep(1.5)
    pagi.mouseUp()
    time.sleep(1)
    pagi.moveTo(386, 758)
    time.sleep(1)
    pagi.click()

    #clicar em ok no final (pop-up)
    pagi.moveTo(x=938, y=552)
    time.sleep(2)
    pagi.click()
    time.sleep(2)
    
    #encontra botão de seleção / voltar para aba Usuario
    time.sleep(1)
    pagi.moveTo(102, 159)
    time.sleep(1)
    pagi.click()
    time.sleep(1.5)
    pagi.moveTo(x=101, y=375)
    time.sleep(1)
    pagi.click() 
    time.sleep(2)
#--------------------------------------------------------|=Indo para Usúario filtrado=|-------------------------------------
    
    #encontra campo usuario
    pagi.moveTo(411, 244)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write(matricula)
    time.sleep(1)

    #encontra campo filtrar
    pagi.moveTo(418, 775)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1)
    
#--------------------------------------------------------|=Gera senha=|-------------------------------------
    #gera senha
    #encontrar o botão gerar senha
    pagi.moveTo(x=1525, y=224) #encontra botão gerar senha
    time.sleep(1.5)
    pagi.click() #clica botão gerar senha
    time.sleep(1)
    pagi.moveTo(x=790, y=462)#encontra campo para digitar senha
    time.sleep(1)
    pagi.write('123tasy') #escreve a senha '123tasy'
    time.sleep(1)
    pagi.moveTo(x=940, y=597) # encontra botão OK
    time.sleep(1)
    pagi.click() #clica botão OK (confirmar criação de senha)
    time.sleep(1.5)
    pagi.moveTo(x=948, y=544) #encontrar botão ok senha gerada com sucesso
    time.sleep(1.5)
    pagi.click() #clica botão ok senha gerada com sucesso
    time.sleep(2)
    
#--------------------------------------------------------|=Indo para filtro icone na tela=|-------------------------------------
    
    #encontra campo usuario
    pagi.moveTo(x=50, y=278) #move mouse no filtro "icone na tala"
    time.sleep(1)
    pagi.click() #clica no filtro "icone na tala"
    time.sleep(1.5)

#--------------------------------------------------------|=Printar o nome/matricula do usuario criado=|------------------
    print('linha: ', linha)
    print('matricula: ',matricula)
    print('nome: ', nome)
    print('___________===============_________________=============__________\n')

data = datetime.now().strftime('%Y-%m-%d')
hora = datetime.now().strftime('%H:%M:%S')
print('\nCriação Usuario Emfermeiro Tasy\n\nFinalizado', 'Data: ', data, '- Hora: ', hora)
pagi.alert('Finalizado')
# Out:
# Criação Usuario Medico Tasy
#
# Inicio Data:  2022-06-02 - Hora:  09:06:00
# linha:  16
# matricula:  6321821
# nome:  CARLOS EDUARDO CAETANO
# ___________===============_________________=============__________
#
# linha:  17
# matricula:  6323629
# nome:  CAROLINE ADAMARIS NEVES SANTOS
# ___________===============_________________=============__________
#
# linha:  18
# matricula:  6323962
# nome:  CASSIA SILENE DA CUNHA
# ___________===============_________________=============__________
#
# linha:  19
# matricula:  6323903
# nome:  CLEIRISLENE FATIMA BRITO VIEIRA
# ___________===============_________________=============__________
#
# linha:  20
# matricula:  6320735
# nome:  CRISTIANE GONCALVES TAVARES
# ___________===============_________________=============__________
#
# linha:  21
# matricula:  6322498
# nome:  DAIANY VIEIRA SCALABRINI SILVA
# ___________===============_________________=============__________
#
# linha:  22
# matricula:  6323934
# ...

# %%
pagi.position()
# Out:
# Point(x=1376, y=397)

# %%
    #rola scroll ate função para evolução/prescição
    pagi.moveTo(1558, 339)
    time.sleep(1.5)
    pagi.mouseDown(x=1558, y=480)
    time.sleep(1.5)
    pagi.mouseUp()
    time.sleep(1)

    #seleciona a função para evolução/prescição
    pagi.moveTo(1092, 586)
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write('fisio')
    time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1)

    #rola scroll ate campo Classe Profissional
    pagi.moveTo(x=1553, y=659)# move mouse
    time.sleep(1.5)
    pagi.click() # desce scroll
    time.sleep(1.5)
    pagi.moveTo(x=1376, y=397)# encontra compo Classe Profissional
    time.sleep(1.5)
    pagi.click()
    time.sleep(1.5)
    pagi.write('fisio')
    time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1)

# %%
pagi.write('fisio')
time.sleep(1.5)
    pagi.press('enter')
    time.sleep(1)
